# %% [markdown]
# ## -------------------------------------USC CED Additional Category Adder---------------------------------

# %% [markdown]
# ---CREATED BY TIMOTHY LABOUNKO---
#
# Purpose of this program is to classify all of the businesses we have in our small business database by Hub Zone and Valley Regions.
# During our previous data cleaning, we lost our latitude, longitude, census tract, and GeoMatch ID. The purpose of this code is to
# recover that.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  # Download respective spreadsheets anch check if they load correctly.

# %%
spreadsheet_name = "C:/Users/User/Downloads/Excel Spreadsheets/USC Center for Economic Development/Compete4LA_Compiled_Spreadsheet_With_Surveys 3.21.23.csv"
new_spreadsheet = pd.read_csv(spreadsheet_name)
new_spreadsheet.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\908700385.py:2: DtypeWarning: Columns (65,67,69,70,72,74,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_spreadsheet = pd.read_csv(spreadsheet_name)
#    COMPETE4LA ID  TIER             COMPANY NAME          BUSINESS ADDRESS  \
# 0        64509.0     2               # 1 BUFFET      14418 HAWTHORNE BLVD
# 1        51524.0     4           $3.99 PIZZA CO          940 N CITRUS AVE
# 2        41914.0     4       $300 DATA RECOVERY    11390 VENTURA BLVD # 5
# 3        68709.0     2  $34.99 DOLLAR MESSENGER  2424 WILSHIRE BLVD # 314
# 4        58918.0     2           007 MOTORS LLC    7017 VAN NUYS BLVD # 5
#
#   BUSINESS CITY BUSINESS STATE  BUSINESS ZIP CODE  BUSINESS ZIP4  \
# 0      LAWNDALE             CA              90260         1517.0
# 1        COVINA             CA              91722         2737.0
# 2   STUDIO CITY             CA              91604         3152.0
# 3   LOS ANGELES             CA              90057         3329.0
# 4      VAN NUYS             CA              91405         3095.0
#
#         PHONE #  FAX #  ...  CALL STATUS IGID  CONTACT FULL NAME OBJECTID_1  \
# 0  3.106444e+09    NaN  ...          NaN  NaN                NaN        NaN
# 1  6.263318e+09    NaN  ...          NaN  NaN                NaN        NaN
# 2  3.232301e+09    NaN  ...          NaN  NaN                NaN        NaN
# 3  2.137250e+09    NaN  ...          NaN  NaN                NaN        NaN
# 4           NaN    NaN  ...          NaN  NaN                NaN        NaN
#
#   Join_Count TARGET_FID SBA-MO SBA-VO SBA-NAO SURVEY
# 0        NaN        NaN     no     no      no     no
# 1        NaN        NaN     no     no      no     no
# 2        NaN        NaN     no     no      no     no
# 3        NaN        NaN     no     no      no     no
# 4        NaN        NaN     no     no      no     no
#
# [5 rows x 97 columns]

# %%
spreadsheet_name = "C:/Users/User/Downloads/Excel Spreadsheets/USC Center for Economic Development/Original Spreadsheet.csv"
old_spreadsheet = pd.read_csv(spreadsheet_name)
old_spreadsheet.head()
# Out:
#   Contact_Full_Name        Company_Name         Mailing_Address Mailing_City  \
# 0               NaN          # 1 BUFFET    14418 HAWTHORNE BLVD     LAWNDALE
# 1     ANGELINA VAFA             #MYDELI     312 E HUNTINGTON DR      ARCADIA
# 2  PEYMAN BALAKHANE       $ 3.99 OUTLET   1620 S LOS ANGELES ST  LOS ANGELES
# 3               NaN      $3.99 PIZZA CO        940 N CITRUS AVE       COVINA
# 4      BRIAN COMETA  $300 DATA RECOVERY  11390 VENTURA BLVD # 5  STUDIO CITY
#
#   Mailing_State  Mailing_Zip_Code  Mailing_Zip_Four Primary_Zip10  \
# 0            CA             90260            1517.0    90260-1517
# 1            CA             91006            3746.0    91006-3746
# 2            CA             90015            3667.0    90015-3667
# 3            CA             91722            2737.0    91722-2737
# 4            CA             91604            3152.0    91604-3152
#
#    Census_Tract   Latitude  ...  Tier  \
# 0        603801  33.900451  ...   NaN
# 1        430801  34.139770  ...   NaN
# 2        224010  34.032421  ...   NaN
# 3        403721  34.096279  ...   4.0
# 4        143800  34.139854  ...   4.0
#
#   Community Plan Areas (What we will use for Valley District)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Sherman Oaks - Studio City - Toluca Lake - Cah...
#
#   LA Council District LA Council District Rep. Senate District  \
# 0                 NaN                      NaN             NaN
# 1                 NaN                      NaN             NaN
# 2                 NaN                      NaN             NaN
# 3                 NaN                      NaN           SD 22
# 4                 4.0             Nithya Raman           SD 27
#
#    Assembly District  Supervisoral District  Congressional District  \
# 0                NaN                    NaN                     NaN
# 1                NaN                    NaN                     NaN
# 2                NaN                    NaN                     NaN
# 3              AD 48                    5.0                    32.0
# 4              AD 44                    5.0                    30.0
#
#    Opportunity Zone (Use Excel)  Hub Zone (Use Excel)
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
#
# [5 rows x 72 columns]

# %%
new_spreadsheet["lat"] = 0
new_spreadsheet["long"] = 0
new_spreadsheet.head()
# Out:
#    COMPETE4LA ID  TIER             COMPANY NAME          BUSINESS ADDRESS  \
# 0        64509.0     2               # 1 BUFFET      14418 HAWTHORNE BLVD
# 1        51524.0     4           $3.99 PIZZA CO          940 N CITRUS AVE
# 2        41914.0     4       $300 DATA RECOVERY    11390 VENTURA BLVD # 5
# 3        68709.0     2  $34.99 DOLLAR MESSENGER  2424 WILSHIRE BLVD # 314
# 4        58918.0     2           007 MOTORS LLC    7017 VAN NUYS BLVD # 5
#
#   BUSINESS CITY BUSINESS STATE  BUSINESS ZIP CODE  BUSINESS ZIP4  \
# 0      LAWNDALE             CA              90260         1517.0
# 1        COVINA             CA              91722         2737.0
# 2   STUDIO CITY             CA              91604         3152.0
# 3   LOS ANGELES             CA              90057         3329.0
# 4      VAN NUYS             CA              91405         3095.0
#
#         PHONE #  FAX #  ...  CONTACT FULL NAME OBJECTID_1  Join_Count  \
# 0  3.106444e+09    NaN  ...                NaN        NaN         NaN
# 1  6.263318e+09    NaN  ...                NaN        NaN         NaN
# 2  3.232301e+09    NaN  ...                NaN        NaN         NaN
# 3  2.137250e+09    NaN  ...                NaN        NaN         NaN
# 4           NaN    NaN  ...                NaN        NaN         NaN
#
#   TARGET_FID SBA-MO SBA-VO SBA-NAO SURVEY lat long
# 0        NaN     no     no      no     no   0    0
# 1        NaN     no     no      no     no   0    0
# 2        NaN     no     no      no     no   0    0
# 3        NaN     no     no      no     no   0    0
# 4        NaN     no     no      no     no   0    0
#
# [5 rows x 99 columns]

# %%
hub_zones_name = "C:/Users/User/Downloads/Excel Spreadsheets/USC Center for Economic Development/Los_Angeles_Hubzones_TableToExcel.csv"
hub_zones = pd.read_csv(hub_zones_name)
hub_zones.head()
# Out:
#         Tract  HUBZone_County_Code              County State OMB_Delineation  \
# 0  6037101110                 6037  Los Angeles County    CA    Metropolitan
# 1  6037101122                 6037  Los Angeles County    CA    Metropolitan
# 2  6037101210                 6037  Los Angeles County    CA    Metropolitan
# 3  6037101220                 6037  Los Angeles County    CA    Metropolitan
# 4  6037101300                 6037  Los Angeles County    CA    Metropolitan
#
#   Status_as_of_Jan_2017        Status_as_of_Jan_2018 Change_  ObjectId
# 0         Not Qualified                Not Qualified     NaN         1
# 1         Not Qualified                Not Qualified     NaN         2
# 2             Qualified  Redesignated until Dec 2021       *         3
# 3             Qualified  Redesignated until Dec 2021       *         4
# 4         Not Qualified                Not Qualified     NaN         5

# %%
valley_region_name = "C:/Users/User/Downloads/Excel Spreadsheets/USC Center for Economic Development/Valley Zip Codes.csv"
valley_region = pd.read_csv(valley_region_name)
valley_region.head()
# Out:
#    ZIP CODE         CITY                      NEIGHBORHOOD  INCOME  LOA  \
# 0   91331.0  Los Angeles     Arleta, Hansen Hills, Pacoima     Low  NaN
# 1   91522.0      Burbank                   Burbank Studios  Middle  NaN
# 2   91330.0  Los Angeles  California State Univ Northridge    High    *
# 3   91303.0  Los Angeles                       Canoga Park    High    *
# 4   91308.0  Los Angeles              Canoga Park PO Boxes    High    *
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Identify all of the Valley Regions.

# %%
for index1 in new_spreadsheet.index:
    for index2 in valley_region.index:
        if new_spreadsheet["BUSINESS ZIP CODE"][index1] == valley_region["ZIP CODE"][index2]:
            new_spreadsheet["VALLEY REGION"][index1] = "Yes"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3149912321.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["VALLEY REGION"][index1] = "Yes"

# %% [markdown]
# # Recover all lost Data.

# %%
# Spreadsheet is organized alphabetically by company name.
old_index = 0

# Keep looping until you get to the end of either spreadsheet.
while old_index < len(old_spreadsheet.index):
    
    # Checks to see if the company name exists in the old spreadsheet.
    if str(old_spreadsheet["Company_Name"][old_index]) in str(new_spreadsheet["COMPANY NAME"]):
        
        new_index = new_spreadsheet.index[new_spreadsheet["COMPANY NAME"]==old_spreadsheet["Company_Name"][old_index]]
        new_spreadsheet["lat"][new_index] = old_spreadsheet["Latitude"][old_index]
        new_spreadsheet["long"][new_index] = old_spreadsheet["Longitude"][old_index]
        new_spreadsheet["GEO MATCH"][new_index] = old_spreadsheet["Geo_Match_Level"][old_index]
        new_spreadsheet["CENSUS TRACT"][new_index] = "06037" + str(old_spreadsheet["Census_Tract"][old_index])
        new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
        # Go to the next new index if match was found.
        new_index += 1
    
    old_index += 1
    # Check to see if we are loading data
    # print(old_index)
    
# We check the tail to see all of the data has been aggregated.
# We can determine this by the last two coluns, the lat and long.
new_spreadsheet.tail()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# Int64Index([1], dtype='int64')
# Int64Index([2], dtype='int64')
# Int64Index([3], dtype='int64')
# Int64Index([4], dtype='int64')
# Int64Index([5], dtype='int64')
# Int64Index([150], dtype='int64')
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3454793729.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["CA SENATE"][new_index] = old_spreadsheet["Senate District"][old_index]
# Int64Index([], dtype='int64')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 8
#       4 # Keep looping until you get to the end of either spreadsheet.
#       5 while old_index < len(old_spreadsheet.index):
#       6
#       7     # Checks to see if the company name exists in the old spreadsheet.
# ----> 8     if str(old_spreadsheet["Company_Name"][old_index]) in str(new_spreadsheet["COMPANY NAME"]):
#      10         new_index = new_spreadsheet.index[new_spreadsheet["COMPANY NAME"]==old_spreadsheet["Company_Name"][old_index]]
#      11         new_spreadsheet["lat"][new_index] = old_spreadsheet["Latitude"][old_index]
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\series.py:1594, in Series.__repr__(self)
#    1590 """
#    1591 Return a string representation for a particular Series.
#    1592 """
#    1593 repr_params = fmt.get_series_repr_params()
# -> 1594 return self.to_string(**repr_params)
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\series.py:1675, in Series.to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1628 def to_string(
#    1629     self,
#    1630     buf: FilePath | WriteBuffer[str] | None = None,
#    (...)
#    1639     min_rows: int | None = None,
#    1640 ) -> str | None:
#    1641     """
#    1642     Render a string representation of the Series.
#    1643
#    (...)
#    1673         String representation of Series if ``buf=None``, otherwise None.
#    1674     """
# -> 1675     formatter = fmt.SeriesFormatter(
#    1676         self,
#    1677         name=name,
#    1678         length=length,
#    1679         header=header,
#    1680         index=index,
#    1681         dtype=dtype,
#    1682         na_rep=na_rep,
#    1683         float_format=float_format,
#    1684         min_rows=min_rows,
#    1685         max_rows=max_rows,
#    1686     )
#    1687     result = formatter.to_string()
#    1689     # catch contract violations
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\io\formats\format.py:299, in SeriesFormatter.__init__(self, series, buf, length, header, index, na_rep, name, float_format, dtype, max_rows, min_rows)
#     296 self.dtype = dtype
#     297 self.adj = get_adjustment()
# --> 299 self._chk_truncate()
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\io\formats\format.py:321, in SeriesFormatter._chk_truncate(self)
#     319     else:
#     320         row_num = max_rows // 2
# --> 321         series = concat((series.iloc[:row_num], series.iloc[-row_num:]))
#     322     self.tr_row_num = row_num
#     323 else:
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\reshape\concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\reshape\concat.py:633, in _Concatenator._get_new_axes(self)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
# --> 633     return [
#     634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\reshape\concat.py:634, in <listcomp>(.0)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
#     633     return [
# --> 634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\reshape\concat.py:691, in _Concatenator._get_concat_axis(self)
#     689     if self.levels is not None:
#     690         raise ValueError("levels supported only when keys is not None")
# --> 691     concat_axis = _concat_indexes(indexes)
#     692 else:
#     693     concat_axis = _make_concat_multiindex(
#     694         indexes, self.keys, self.levels, self.names
#     695     )
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\reshape\concat.py:709, in _concat_indexes(indexes)
#     708 def _concat_indexes(indexes) -> Index:
# --> 709     return indexes[0].append(indexes[1:])
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\indexes\base.py:5405, in Index.append(self, other)
#    5402 names = {obj.name for obj in to_concat}
#    5403 name = None if len(names) > 1 else self.name
# -> 5405 return self._concat(to_concat, name)
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\indexes\range.py:930, in RangeIndex._concat(self, indexes, name)
#     926 non_consecutive = (step != rng.step and len(rng) > 1) or (
#     927     next_ is not None and rng.start != next_
#     928 )
#     929 if non_consecutive:
# --> 930     result = Int64Index(np.concatenate([x._values for x in rng_indexes]))
#     931     return result.rename(name)
#     933 if step is not None:
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\indexes\range.py:930, in <listcomp>(.0)
#     926 non_consecutive = (step != rng.step and len(rng) > 1) or (
#     927     next_ is not None and rng.start != next_
#     928 )
#     929 if non_consecutive:
# --> 930     result = Int64Index(np.concatenate([x._values for x in rng_indexes]))
#     931     return result.rename(name)
#     933 if step is not None:
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\indexes\base.py:5114, in Index._values(self)
#    5090 @property
#    5091 def _values(self) -> ExtensionArray | np.ndarray:
#    5092     """
#    5093     The best array representation.
#    5094
#    (...)
#    5112     values : Values
#    5113     """
# -> 5114     return self._data
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\mambaforge\envs\ppd599\lib\site-packages\pandas\core\indexes\range.py:202, in RangeIndex._data(self)
#     195 @cache_readonly
#     196 def _data(self) -> np.ndarray:  # type: ignore[override]
#     197     """
#     198     An int array that for performance reasons is created only when needed.
#     199
#     200     The constructed array is saved in ``_cache``.
#     201     """
# --> 202     return np.arange(self.start, self.stop, self.step, dtype=np.int64)
#
# KeyboardInterrupt:

# %% [markdown]
# # Identify all of the Hub Zones.

# %%
for index1 in new_spreadsheet.index:
    for index2 in hub_zones.index:
        if str(new_spreadsheet["CENSUS TRACT"][index1]) == "0" + str(hub_zones["Tract"][index2]):
            if hub_zones["Status_as_of_Jan_2018"][index2] == "Qualified":
                new_spreadsheet["HUB ZONE"][index1] = "Yes"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\1779822300.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_spreadsheet["HUB ZONE"][index1] = "Yes"

# %%
new_spreadsheet["HUB ZONE"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    Yes
# 4    NaN
# Name: HUB ZONE, dtype: object

# %% [markdown]
# # Make a final Spreadsheet.

# %%
new_spreadsheet.to_csv("C:/Users/User/Downloads/Excel Spreadsheets/USC Center for Economic Development/Spreadsheet_as_3.27.csv")

# %% [markdown]
# END OF CODE (Last Edited 3/27)
